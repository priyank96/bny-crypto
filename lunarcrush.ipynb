# %%
import urllib.request
import ssl
import json
import time
import tweepy


ssl._create_default_https_context = ssl._create_unverified_context

api_key = "npw43ez4a8itkgai3il6ybw8l8uu0kj9e9o6lkbi"

# Allows adding as many coins as desired
coin_list = [
    "LTC",
    "ETH",
    "BTC"

    
]
coins = ','.join(coin_list)

# A list of the fields desired from the API - key is the Lunar Crush key, and the value is the field name outputted to Twitter
# {"LUNAR_CRUSH_KEY": "RENDERED_NAME"}
# For example, to add tweet_replies, you would add:
# {"tweet_replies": "Tweet Replies: "},
# to the list below.
map = [
    {"name":""},
    {"symbol": ""},
    {"price": " Price: "},
    {"percent_change_24h": " - 24 Hour Percent Change: "},
    {"market_cap": " Market Cap: "},
    {"volume_24h": " 24 Hour Volume: "},
    {"url_shares": " URL Shares: "},
    {"reddit_posts": " Reddit Posts: "},
    {"tweets": " Tweets: "},
    {"galaxy_score": " Galaxy Score: "},
    {"volatility": " Volatility: "},
    {"social_volume": " Social Volume: "},
    {"news": " News: "},
    {"close": " Close: "},
]

def final_render(asset_coin, value, key, asset):
    # As the program becomes more complex, this should be written in a more robust manner
    if key == 'symbol':
        asset_coin += " (" + asset[key] + ")"
    elif key == 'percent_change_24h':
        asset_coin += value + str(asset[key]) + "%"
    else:
        asset_coin += value + str(asset[key])
    return asset_coin


# Iterates over each of the fields from Lunar Crush, gets the value from Lunar Crush and renders it with the field name
def main():

    for coin in coin_list:
        url = "https://api.lunarcrush.com/v2?data=assets&key=" + api_key + "&symbol=" + coin
        assets = json.loads(urllib.request.urlopen(url).read())

        for asset in assets['data']:
            # print(asset)
            # print("\n\n")
            asset_coin = ""
            
            for field in map:
                key = list(field.keys())[0]
                value = list(field.values())[0]
                asset_coin = final_render(asset_coin, value, key, asset)
            print(asset_coin)
            print(len(asset_coin))


    # Runs main() every 30 minutes
# while True:
main()
    # time.sleep(1800)
# Out:
# Litecoin (LTC) Price: 54.06424682 - 24 Hour Percent Change: -0.83% Market Cap: 3856282202 24 Hour Volume: 535676730.71 URL Shares: 64 Reddit Posts: 2 Tweets: 151 Galaxy Score: 54 Volatility: 0.00728822 Social Volume: 159 News: 1 Close: 54.06424682
# 247
# Ethereum (ETH) Price: 1359.47946066 - 24 Hour Percent Change: 0.56% Market Cap: 166782133176 24 Hour Volume: 20935860846.32 URL Shares: 2651 Reddit Posts: 15 Tweets: 8191 Galaxy Score: 50.5 Volatility: 0.01230086 Social Volume: 8350 News: 5 Close: 1359.47946066
# 261
# Bitcoin (BTC) Price: 20082.69746497 - 24 Hour Percent Change: -0.35% Market Cap: 385009911708 24 Hour Volume: 66649447932.31 URL Shares: 2449 Reddit Posts: 38 Tweets: 12837 Galaxy Score: 51.5 Volatility: 0.01228885 Social Volume: 13276 News: 17 Close: 20082.69746497
# 266

# %%
# %pip install tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tweepy in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (4.10.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from tweepy) (3.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request
import ssl
import json
import time
import tweepy
import pandas


ssl._create_default_https_context = ssl._create_unverified_context

api_key = "npw43ez4a8itkgai3il6ybw8l8uu0kj9e9o6lkbi"

# Allows adding as many coins as desired
coin_list = [
    "LTC","ETH","BTC"
]
coins = ','.join(coin_list)


map = [
    {"name":""},
    {"symbol": ""},
    {"price": " Price: "},
    {"percent_change_24h": " - 24 Hour Percent Change: "},
    {"market_cap": " Market Cap: "},
    {"volume_24h": " 24 Hour Volume: "},
    {"url_shares": " URL Shares: "},
    {"reddit_posts": " Reddit Posts: "},
    {"tweets": " Tweets: "},
    {"galaxy_score": " Galaxy Score: "},
    {"volatility": " Volatility: "},
    {"social_volume": " Social Volume: "},
    {"news": " News: "},
    {"close": " Close: "},
    {'time': ' Time:'},
]

fields = [list(key.keys())[0] for key in map]
coins_df = pandas.DataFrame(columns=fields)

def final_render(asset_coin, value, key, asset):
    if key == 'symbol':
        asset_coin += " (" + asset[key] + ")"
    elif key == 'percent_change_24h':
        asset_coin += value + str(asset[key]) + "%"
    else:
        asset_coin += value + str(asset[key])
    return asset_coin


# Iterates over each of the fields from Lunar Crush, gets the value from Lunar Crush and renders it with the field name
def main():

    all_coins = []
    for coin in coin_list:
        url = "https://api.lunarcrush.com/v2?data=assets&key=" + api_key + "&symbol=" + coin
        assets = json.loads(urllib.request.urlopen(url).read())

        # print(assets['data'][0])

        for asset in assets['data']:
            asset_coin = ""
            for field in map:
                key = list(field.keys())[0]
                value = list(field.values())[0]
                asset_coin = final_render(asset_coin, value, key, asset)
            print(asset_coin)
            print(len(asset_coin))

        all_coins.append(assets)
        
    return all_coins
        
def create_coins_df(assets):
    global coins_df

    print(len(assets))

    for n in range(len(coin_list)):
        data = assets[n]['data'][0]
        
        required_data = [{key: data[key] for key in fields}]
        coins_df = coins_df.append(required_data, ignore_index = True)
        # coins_df['time'] = pandas.to_datetime(coins_df['time'])
        
    return coins_df

create_coins_df(main())
# Out:
# Litecoin (LTC) Price: 54.06424682 - 24 Hour Percent Change: -0.83% Market Cap: 3856282202 24 Hour Volume: 535676730.71 URL Shares: 64 Reddit Posts: 2 Tweets: 151 Galaxy Score: 54 Volatility: 0.00728822 Social Volume: 159 News: 1 Close: 54.06424682 Time:1665082800
# 263
# Ethereum (ETH) Price: 1359.47946066 - 24 Hour Percent Change: 0.56% Market Cap: 166782133176 24 Hour Volume: 20935860846.32 URL Shares: 2651 Reddit Posts: 15 Tweets: 8191 Galaxy Score: 50.5 Volatility: 0.01230086 Social Volume: 8350 News: 5 Close: 1359.47946066 Time:1665082800
# 277
# Bitcoin (BTC) Price: 20082.69746497 - 24 Hour Percent Change: -0.35% Market Cap: 385009911708 24 Hour Volume: 66649447932.31 URL Shares: 2449 Reddit Posts: 38 Tweets: 12837 Galaxy Score: 51.5 Volatility: 0.01228885 Social Volume: 13276 News: 17 Close: 20082.69746497 Time:1665082800
# 282
# 3
# /var/folders/k0/xsc0r38j2976t9q024vjvbt40000gn/T/ipykernel_31914/3594448972.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coins_df = coins_df.append(required_data, ignore_index = True)
# /var/folders/k0/xsc0r38j2976t9q024vjvbt40000gn/T/ipykernel_31914/3594448972.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coins_df = coins_df.append(required_data, ignore_index = True)
# /var/folders/k0/xsc0r38j2976t9q024vjvbt40000gn/T/ipykernel_31914/3594448972.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coins_df = coins_df.append(required_data, ignore_index = True)
#        name symbol         price  percent_change_24h    market_cap  \
# 0  Litecoin    LTC     54.064247               -0.83    3856282202
# 1  Ethereum    ETH   1359.479461                0.56  166782133176
# 2   Bitcoin    BTC  20082.697465               -0.35  385009911708
#
#      volume_24h url_shares reddit_posts tweets galaxy_score  volatility  \
# 0  5.356767e+08         64            2    151           54    0.007288
# 1  2.093586e+10       2651           15   8191         50.5    0.012301
# 2  6.664945e+10       2449           38  12837         51.5    0.012289
#
#   social_volume news         close        time
# 0           159    1     54.064247  1665082800
# 1          8350    5   1359.479461  1665082800
# 2         13276   17  20082.697465  1665082800

# %%
import requests

url = "https://lunarcrush.com/api3/coins/global/change"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
