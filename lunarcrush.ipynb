# %%
import urllib.request
import ssl
import json
import time
import tweepy


ssl._create_default_https_context = ssl._create_unverified_context

# api_key = "npw43ez4a8itkgai3il6ybw8l8uu0kj9e9o6lkbi"
# api_key = "1ghujiww8wjaw46fwph6b2joo7l992v21uth0qy1m"
api_key = "8uk16suw8ooj6ht6pacgqidgt5l8uujk8qj5n27lr"

# Allows adding as many coins as desired
coin_list = [
    "LTC",
    "ETH",
    "BTC"

    
]
coins = ','.join(coin_list)

# A list of the fields desired from the API - key is the Lunar Crush key, and the value is the field name outputted to Twitter
# {"LUNAR_CRUSH_KEY": "RENDERED_NAME"}
# For example, to add tweet_replies, you would add:
# {"tweet_replies": "Tweet Replies: "},
# to the list below.
map = [
    {"name":""},
    {"symbol": ""},
    {"price": " Price: "},
    {"percent_change_24h": " - 24 Hour Percent Change: "},
    {"market_cap": " Market Cap: "},
    {"volume_24h": " 24 Hour Volume: "},
    {"url_shares": " URL Shares: "},
    {"reddit_posts": " Reddit Posts: "},
    {"tweets": " Tweets: "},
    {"galaxy_score": " Galaxy Score: "},
    {"volatility": " Volatility: "},
    {"social_volume": " Social Volume: "},
    {"news": " News: "},
    {"close": " Close: "},
]

def final_render(asset_coin, value, key, asset):
    # As the program becomes more complex, this should be written in a more robust manner
    if key == 'symbol':
        asset_coin += " (" + asset[key] + ")"
    elif key == 'percent_change_24h':
        asset_coin += value + str(asset[key]) + "%"
    else:
        asset_coin += value + str(asset[key])
    return asset_coin


# Iterates over each of the fields from Lunar Crush, gets the value from Lunar Crush and renders it with the field name
def main():

    for coin in coin_list:
        url = "https://api.lunarcrush.com/v2?data=assets&key=" + api_key + "&symbol=" + coin
        assets = json.loads(urllib.request.urlopen(url).read())

        for asset in assets['data']:
            # print(asset)
            # print("\n\n")
            asset_coin = ""
            
            for field in map:
                key = list(field.keys())[0]
                value = list(field.values())[0]
                asset_coin = final_render(asset_coin, value, key, asset)
            print(asset_coin)
            print(len(asset_coin))


    # Runs main() every 30 minutes
# while True:
main()
    # time.sleep(1800)
# Out:
# Litecoin (LTC) Price: 51.16861808 - 24 Hour Percent Change: -0.47% Market Cap: 3652701645 24 Hour Volume: 550944887.34 URL Shares: 16 Reddit Posts: 1 Tweets: 67 Galaxy Score: 59.5 Volatility: 0.00770555 Social Volume: 73 News: 1 Close: 51.16861808
# 247
# Ethereum (ETH) Price: 1293.29310537 - 24 Hour Percent Change: 0.24% Market Cap: 158813348279 24 Hour Volume: 24243259201.82 URL Shares: 2142 Reddit Posts: 14 Tweets: 5484 Galaxy Score: 66 Volatility: 0.00448524 Social Volume: 5648 News: 5 Close: 1293.29310537
# 259
# Bitcoin (BTC) Price: 19154.09242843 - 24 Hour Percent Change: -1.27% Market Cap: 367361835909 24 Hour Volume: 76961382091.23 URL Shares: 1862 Reddit Posts: 39 Tweets: 8192 Galaxy Score: 65 Volatility: 0.00348632 Social Volume: 8502 News: 9 Close: 19154.09242843
# 261

# %%
# %pip install tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tweepy in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (4.10.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from tweepy) (3.2.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ShivaniButala/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.24)
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request
import ssl
import json
import time
import tweepy
import pandas


ssl._create_default_https_context = ssl._create_unverified_context

api_key = "npw43ez4a8itkgai3il6ybw8l8uu0kj9e9o6lkbi"

# Allows adding as many coins as desired
coin_list = [
    "LTC","ETH","BTC"
]
coins = ','.join(coin_list)


map = [
    {"name":""},
    {"symbol": ""},
    {"price": " Price: "},
    {"percent_change_24h": " - 24 Hour Percent Change: "},
    {"market_cap": " Market Cap: "},
    {"volume_24h": " 24 Hour Volume: "},
    {"url_shares": " URL Shares: "},
    {"reddit_posts": " Reddit Posts: "},
    {"tweets": " Tweets: "},
    {"galaxy_score": " Galaxy Score: "},
    {"volatility": " Volatility: "},
    {"social_volume": " Social Volume: "},
    {"news": " News: "},
    {"close": " Close: "},
    {'time': ' Time:'},
]

fields = [list(key.keys())[0] for key in map]
coins_df = pandas.DataFrame(columns=fields)

def final_render(asset_coin, value, key, asset):
    if key == 'symbol':
        asset_coin += " (" + asset[key] + ")"
    elif key == 'percent_change_24h':
        asset_coin += value + str(asset[key]) + "%"
    else:
        asset_coin += value + str(asset[key])
    return asset_coin


# Iterates over each of the fields from Lunar Crush, gets the value from Lunar Crush and renders it with the field name
def main():

    all_coins = []
    for coin in coin_list:
        url = "https://api.lunarcrush.com/v2?data=assets&key=" + api_key + "&symbol=" + coin
        assets = json.loads(urllib.request.urlopen(url).read())

        # print(assets['data'][0])

        for asset in assets['data']:
            asset_coin = ""
            for field in map:
                key = list(field.keys())[0]
                value = list(field.values())[0]
                asset_coin = final_render(asset_coin, value, key, asset)
            print(asset_coin)
            print(len(asset_coin))

        all_coins.append(assets)
        
    return all_coins
        
def create_coins_df(assets):
    global coins_df

    print(len(assets))

    for n in range(len(coin_list)):
        data = assets[n]['data'][0]
        
        required_data = [{key: data[key] for key in fields}]
        coins_df = coins_df.append(required_data, ignore_index = True)
        # coins_df['time'] = pandas.to_datetime(coins_df['time'])
        
    return coins_df

create_coins_df(main())
# Out:
# Litecoin (LTC) Price: 51.09940116 - 24 Hour Percent Change: -0.6% Market Cap: 3647760555 24 Hour Volume: 548083293.32 URL Shares: 25 Reddit Posts: 1 Tweets: 119 Galaxy Score: 58 Volatility: 0.0076591 Social Volume: 127 News: 1 Close: 51.09940116 Time:1665784800
# 261
# Ethereum (ETH) Price: 1292.43002539 - 24 Hour Percent Change: 0.18% Market Cap: 158706586047 24 Hour Volume: 24134464192.89 URL Shares: 2231 Reddit Posts: 11 Tweets: 5624 Galaxy Score: 66 Volatility: 0.00447568 Social Volume: 5774 News: 7 Close: 1292.43002539 Time:1665784800
# 275
# Bitcoin (BTC) Price: 19128.62887512 - 24 Hour Percent Change: -1.4% Market Cap: 366873463112 24 Hour Volume: 76650570543.19 URL Shares: 1941 Reddit Posts: 29 Tweets: 8284 Galaxy Score: 64.5 Volatility: 0.0034839 Social Volume: 8591 News: 10 Close: 19128.62887512 Time:1665784800
# 278
# 3
# /var/folders/k0/xsc0r38j2976t9q024vjvbt40000gn/T/ipykernel_83539/3594448972.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coins_df = coins_df.append(required_data, ignore_index = True)
# /var/folders/k0/xsc0r38j2976t9q024vjvbt40000gn/T/ipykernel_83539/3594448972.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coins_df = coins_df.append(required_data, ignore_index = True)
# /var/folders/k0/xsc0r38j2976t9q024vjvbt40000gn/T/ipykernel_83539/3594448972.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coins_df = coins_df.append(required_data, ignore_index = True)
#        name symbol         price  percent_change_24h    market_cap  \
# 0  Litecoin    LTC     51.099401               -0.60    3647760555
# 1  Ethereum    ETH   1292.430025                0.18  158706586047
# 2   Bitcoin    BTC  19128.628875               -1.40  366873463112
#
#      volume_24h url_shares reddit_posts tweets galaxy_score  volatility  \
# 0  5.480833e+08         25            1    119           58    0.007659
# 1  2.413446e+10       2231           11   5624           66    0.004476
# 2  7.665057e+10       1941           29   8284         64.5    0.003484
#
#   social_volume news         close        time
# 0           127    1     51.099401  1665784800
# 1          5774    7   1292.430025  1665784800
# 2          8591   10  19128.628875  1665784800

# %%
import requests

url = "https://lunarcrush.com/api3/coins/global/change"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
# Out:
# b'{"error":"Error: Not authorized (2)"}'

# %%
import requests

url = "https://lunarcrush.com/api3/coins/2/influencers"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
# Out:
# b'{"error":"Error: Not authorized (2)"}'

# %%
import requests

url = "https://lunarcrush.com/api3/coins/2/time-series"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
# Out:
# b'{"error":"Error: Not authorized (2)"}'

# %%
import requests

url = "https://lunarcrush.com/api3/coinoftheday"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
# Out:
# b'{"name":"Algorand","symbol":"ALGO"}'

# %%
import requests

url = "https://lunarcrush.com/api3/coinoftheday/info"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
# Out:
# b'{"last_changed":1665748800,"history":[{"id":339,"symbol":"AUTO","name":"Cube","last_cotd":1554915170},{"id":289,"symbol":"TNB","name":"Time New Bank","last_cotd":1555174698},{"id":312,"symbol":"TPAY","name":"TokenPay","last_cotd":1557595298},{"id":199,"symbol":"MITH","name":"Mithril","last_cotd":1558114551},{"id":197,"symbol":"GNO","name":"Gnosis","last_cotd":1558201055},{"id":317,"symbol":"QSP","name":"Quantstamp","last_cotd":1558373857},{"id":125,"symbol":"NULS","name":"Nuls","last_cotd":1558981059},{"id":9,"symbol":"BSV","name":"Bitcoin SV","last_cotd":1559240669},{"id":310,"symbol":"DATA","name":"Streamr","last_cotd":1560197065},{"id":259,"symbol":"MDA","name":"Moeda Loyalty Points","last_cotd":1561582385},{"id":228,"symbol":"VITAE","name":"Vitae","last_cotd":1561668810},{"id":69,"symbol":"NRG","name":"Energi","last_cotd":1561755219},{"id":61,"symbol":"BTM","name":"Bytom","last_cotd":1562447871},{"id":62,"symbol":"LAMB","name":"Lambda","last_cotd":1562707701},{"id":247,"symbol":"IQ","name":"Everipedia","last_cotd":1562794341},{"id":287,"symbol":"AEON","name":"Aeon","last_cotd":1562967735},{"id":155,"symbol":"ABT","name":"Arcblock","last_cotd":1563400387},{"id":309,"symbol":"B2B","name":"B2BX","last_cotd":1563573709},{"id":190,"symbol":"FUN","name":"FunFair","last_cotd":1564093040},{"id":160,"symbol":"ANT","name":"Aragon","last_cotd":1564352354},{"id":133,"symbol":"IGNIS","name":"Ignis","last_cotd":1564698153},{"id":180,"symbol":"LXT","name":"Litex","last_cotd":1565044951},{"id":166,"symbol":"TEL","name":"Telcoin","last_cotd":1565304396},{"id":127,"symbol":"VERI","name":"Veritaseum","last_cotd":1566344117},{"id":65,"symbol":"EKT","name":"EDUCare","last_cotd":1566517600},{"id":7,"symbol":"USDT","name":"Tether","last_cotd":1568993166},{"id":2032,"symbol":"WIN","name":"WINk","last_cotd":1568993212},{"id":137,"symbol":"LOOM","name":"Loom Network","last_cotd":1568993268},{"id":79,"symbol":"ABBC","name":"ABBC Coin","last_cotd":1569474888},{"id":14,"symbol":"LEO","name":"UNUS SED LEO","last_cotd":1569564084},{"id":88,"symbol":"MAID","name":"MaidSafeCoin","last_cotd":1570276800},{"id":34,"symbol":"QTUM","name":"Qtum","last_cotd":1572868800},{"id":27,"symbol":"VSYS","name":"V Systems","last_cotd":1575460800},{"id":44,"symbol":"BTT","name":"BitTorrent","last_cotd":1577707200},{"id":89,"symbol":"ELF","name":"aelf","last_cotd":1577793600},{"id":84,"symbol":"ARDR","name":"Ardor","last_cotd":1577880000},{"id":12,"symbol":"TRX","name":"TRON","last_cotd":1578312000},{"id":75,"symbol":"WTC","name":"Walton","last_cotd":1582804800},{"id":36,"symbol":"HT","name":"Huobi Token","last_cotd":1582977600},{"id":43,"symbol":"LSK","name":"Lisk","last_cotd":1584532800},{"id":103,"symbol":"ZEN","name":"Horizen","last_cotd":1585483200},{"id":60,"symbol":"BCN","name":"Bytecoin","last_cotd":1586347200},{"id":185,"symbol":"DRGN","name":"Dragonchain","last_cotd":1589630400},{"id":150,"symbol":"PIVX","name":"PIVX","last_cotd":1589803200},{"id":57,"symbol":"BTS","name":"BitShares","last_cotd":1592481600},{"id":81,"symbol":"XZC","name":"Zcoin","last_cotd":1593000000},{"id":77,"symbol":"STEEM","name":"Steem","last_cotd":1593259200},{"id":16,"symbol":"NEO","name":"NEO","last_cotd":1595419200},{"id":49,"symbol":"ZRX","name":"0x","last_cotd":1598011200},{"id":149,"symbol":"BEAM","name":"BEAM","last_cotd":1603281600},{"id":434,"symbol":"LEND","name":"Aave (Old)","last_cotd":1604923200},{"id":86,"symbol":"GNT","name":"Golem","last_cotd":1605009600},{"id":15,"symbol":"DASH","name":"Dash","last_cotd":1607774400},{"id":2220,"symbol":"AMPL","name":"Ampleforth","last_cotd":1607860800},{"id":35,"symbol":"DCR","name":"Decred","last_cotd":1609416000},{"id":17,"symbol":"MIOTA","name":"IOTA","last_cotd":1612612800},{"id":2151,"symbol":"BAND","name":"Band Protocol","last_cotd":1613131200},{"id":143,"symbol":"BNT","name":"Bancor","last_cotd":1615032000},{"id":50,"symbol":"NPXS","name":"Pundi X","last_cotd":1615723200},{"id":145,"symbol":"WAN","name":"Wanchain","last_cotd":1617 ...

# %%
import requests

url = "https://lunarcrush.com/api3/coins/global/time-series"
headers = {
  'Authorization': 'Bearer <TOKEN>'
}

response = requests.request("GET", url, headers=headers)

print(response.text.encode('utf8'))
# Out:
# b'{"timeSeries":[{"time":1665183600,"volume":4561262124,"market_cap":975555933611,"url_shares":12856,"unique_url_shares":584,"reddit_posts":102,"reddit_posts_score":1232,"reddit_comments":308,"reddit_comments_score":1945,"tweets":48240,"tweet_spam":36919,"tweet_followers":114241074,"tweet_quotes":1582,"tweet_retweets":15402,"tweet_replies":8017,"tweet_favorites":50634,"tweet_sentiment1":1237,"tweet_sentiment2":6280,"tweet_sentiment3":6322,"tweet_sentiment4":29677,"tweet_sentiment5":4724